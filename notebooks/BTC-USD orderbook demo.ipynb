# %% [markdown]
# ### Downloaded sample from https://datashop.cboe.com/cryptocurrency-gemini-order-book-data

# %%
import pandas as pd

# %%
df = pd.read_csv('BTCUSD_order_book_20170210.zip')

# %%
df.head()
# Out:
#    Event ID  Event Date Event Time  Event Millis  Order ID Execution Options  \
# 0   1053910  2015-10-28   06:03:54            93   1053910               NaN
# 1   1053925  2015-10-28   06:04:09           658   1053925               NaN
# 2   1054202  2015-10-28   06:15:50           883   1054202               NaN
# 3   1054205  2015-10-28   06:16:03            23   1054205               NaN
# 4   1054208  2015-10-28   06:16:12           593   1054208               NaN
#
#   Event Type  Symbol Order Type  Side  Limit Price (USD)  \
# 0    Initial  BTCUSD      limit  sell           999999.0
# 1    Initial  BTCUSD      limit  sell           799999.0
# 2    Initial  BTCUSD      limit  sell           599999.0
# 3    Initial  BTCUSD      limit  sell           399999.0
# 4    Initial  BTCUSD      limit  sell           199999.0
#
#    Original Quantity (BTC)  Gross Notional Value (USD)  Fill Price (USD)  \
# 0                      0.1                         NaN               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245912 entries, 0 to 245911
# Data columns (total 18 columns):
# Event ID                      245912 non-null int64
# Event Date                    245912 non-null object
# Event Time                    245912 non-null object
# Event Millis                  245912 non-null int64
# Order ID                      245912 non-null int64
# Execution Options             195267 non-null object
# Event Type                    245912 non-null object
# Symbol                        245912 non-null object
# Order Type                    245912 non-null object
# Side                          245912 non-null object
# Limit Price (USD)             245554 non-null float64
# Original Quantity (BTC)       245702 non-null float64
# Gross Notional Value (USD)    88 non-null float64
# Fill Price (USD)              3078 non-null float64
# Fill Quantity (BTC)           3078 non-null float64
# Total Exec Quantity (BTC)     245912 non-null float64
# ...

# %%
df.describe()
# Out:
#            Event ID   Event Millis      Order ID  Limit Price (USD)  \
# count  2.459120e+05  245912.000000  2.459120e+05      245554.000000
# mean   3.748572e+08     498.540994  3.748553e+08        1103.972509
# std    4.311656e+06     289.674259  4.319148e+06        5786.870922
# min    1.053910e+06       0.000000  1.053910e+06           0.010000
# 25%    3.746459e+08     247.000000  3.746455e+08         967.690000
# 50%    3.748903e+08     498.000000  3.748896e+08         979.880000
# 75%    3.751942e+08     750.250000  3.751920e+08         997.660000
# max    3.756443e+08     999.000000  3.756443e+08     1000000.000000
#
#        Original Quantity (BTC)  Gross Notional Value (USD)  Fill Price (USD)  \
# count            245702.000000                   88.000000       3078.000000
# mean                  8.048289                 2265.395227        986.230734
# std                  43.411658                 3962.474787         14.436711
# ...
