# %%
import pandas as pd
import json
from datetime import datetime
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.tools import FigureFactory as FF
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
cols = ['date','timestamp','exchange','symbol','bids','asks']
df = pd.read_csv("data/orderbook/hitbtc2.ETH-USDT.csv", 
                 sep=';',
                 names=cols, 
                 parse_dates=['date'],
                 dtype={'exchange':'category', 'symbol':'category'}
                )[['date','exchange','symbol','bids','asks']].set_index('date')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2224 entries, 2018-05-25 11:06:27.925992 to 2018-05-25 13:08:08.092301
# Data columns (total 4 columns):
# exchange    2224 non-null category
# symbol      2224 non-null category
# bids        2224 non-null object
# asks        2224 non-null object
# dtypes: category(2), object(2)
# memory usage: 56.5+ KB

# %%
df.head(3)
# Out:
#                            exchange    symbol  \
# date
# 2018-05-25 11:06:27.925992  hitbtc2  ETH/USDT
# 2018-05-25 11:13:43.893513  hitbtc2  ETH/USDT
# 2018-05-25 11:17:04.425172  hitbtc2  ETH/USDT
#
#                                                                          bids  \
# date
# 2018-05-25 11:06:27.925992  [[589.4, 3.311], [589.39, 0.02], [589.25, 1.75...
# 2018-05-25 11:13:43.893513  [[591.55, 2.403], [591.34, 0.718], [591.33, 1....
# 2018-05-25 11:17:04.425172  [[591.17, 2.948], [591.16, 0.026], [591.11, 0....
#
#                                                                          asks
# date
# 2018-05-25 11:06:27.925992  [[590.07, 5.0], [590.09, 2.5], [590.12, 0.873]...
# 2018-05-25 11:13:43.893513  [[592.3, 0.038], [592.31, 5.0], [592.32, 0.02]...
# 2018-05-25 11:17:04.425172  [[591.31, 0.005], [591.54, 0.026], [591.55, 0....

# %%
bids = json.loads(df.iloc[0].bids)
asks = json.loads(df.iloc[0].asks)

# %%
list(zip(bids, asks))
# Out:
# [([589.4, 3.311], [590.07, 5.0]),
#  ([589.39, 0.02], [590.09, 2.5]),
#  ([589.25, 1.757], [590.12, 0.873]),
#  ([589.19, 0.71], [590.2, 0.031]),
#  ([589.15, 0.003], [590.21, 1.69]),
#  ([589.14, 10.0], [590.28, 0.031]),
#  ([589.04, 0.031], [590.36, 0.031]),
#  ([589.01, 3.012], [590.46, 0.031]),
#  ([588.93, 5.094], [590.55, 0.1]),
#  ([588.86, 1.924], [590.56, 0.031]),
#  ([588.62, 37.154], [590.96, 0.04]),
#  ([588.52, 3.306], [590.97, 0.71]),
#  ([588.35, 12.676], [590.98, 0.013]),
#  ([588.07, 4.946], [590.99, 0.031]),
#  ([587.64, 0.1], [591.0, 10.0]),
#  ([587.59, 6.76], [591.08, 1.757]),
#  ([587.46, 9.0], [591.18, 2.886]),
#  ([586.77, 0.152], [591.19, 21.4]),
#  ([586.71, 46.061], [591.28, 4.769]),
#  ([586.54, 0.009], [591.33, 1.874]),
#  ([586.17, 0.033], [591.36, 0.001]),
#  ([585.84, 0.004], [591.4, 0.001]),
#  ([585.83, 0.004], [591.57, 0.001]),
#  ([585.73, 0.052], [591.63, 6.777]),
#  ([585.72, 0.042], [591.74, 15.116]),
#  ([585.66, 0.045], [591.96, 30.0]),
# ...
